# %% [markdown]
# <a href="https://colab.research.google.com/github/robsoncdesouza/PA_Python/blob/main/Exerc%C3%ADcios_PA_Listas_Tuplas_Dicionarios_ALUNOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercícios**
# ##Exercício 1: Manipulação de Listas
#
# - Defina uma lista com 5 nomes de cidades.
# - Adicione uma nova cidade ao final da lista.
# - Remova a segunda cidade da lista.
# - Imprima a lista resultante.

# %%
# seu código aqui...
list_cidades = (['Ribeirão Pires', 'Mauá', 'Santo André', 'Suzano', 'São Caetano'])
list_cidades.append ('Rio Grande da Serra')
list_cidades.remove (list_cidades[1])
print (list_cidades)
# Out:
# ['Ribeirão Pires', 'Santo André', 'Suzano', 'São Caetano', 'Rio Grande da Serra']

# %% [markdown]
# ##Exercício 2: Operações com Tuplas
#
# - Defina uma tupla com 4 cores.
# - Crie uma nova tupla que seja a concatenação da tupla original com outra contendo mais 2 cores.
# - Imprima a nova tupla.

# %%
# seu código aqui...
cores = ('Verde', 'Vermelho')
cores2 = cores + ('Violeta', 'Vinho')
print (cores2)
# Out:
# ('Verde', 'Vermelho', 'Violeta', 'Vinho')

# %% [markdown]
# ##Exercício 3: Dicionários Simples
#
# Crie um dicionário para representar um aluno, contendo "nome", "idade" e "curso".
# - Atualize a idade do aluno.
# - Adicione uma nova chave "nota" com um valor.
# - Imprima o dicionário atualizado

# %%
# seu código aqui...
aluno = {
    "Nome": 'Robson',
    "Idade": 15,
    "Curso": 'Informática para Internet',
}
print (aluno)
aluno ["Idade"] = 16
aluno ["Nota"] = 'MB'
print(aluno)
# Out:
# {'Nome': 'Robson', 'Idade': 15, 'Curso': 'Informática para Internet'}
# {'Nome': 'Robson', 'Idade': 16, 'Curso': 'Informática para Internet', 'Nota': 'MB'}

# %% [markdown]
# ##Exercício 4: Listas e Dicionários
#
# - Crie uma lista de dicionários, onde cada dicionário representa um produto com as chaves "nome" e "preço".
# - Adicione um novo produto à lista.
# - Atualize o preço do primeiro produto na lista.
# - Imprima a lista resultante.

# %%
# seu código aqui...
listas_dicio = [
  {"Nome": 'Garrafa', "Preço": 20.99},
  {"Nome": 'Prato', "Preço": 10.99},
  {"Nome": 'Vassoura', "Preço": 7.99}
 ]
listas_dicio.append ({"Nome": 'Rodo', "Preço": 8.99})
listas_dicio2 = {"Nome": 'Garrafa', "Preço": 21.99}
listas_dicio[0].update (listas_dicio2)

print(listas_dicio)
# Out:
# [{'Nome': 'Copo', 'Preço': 3.99}, {'Nome': 'Prato', 'Preço': 10.99}, {'Nome': 'Vassoura', 'Preço': 7.99}, {'Nome': 'Rodo', 'Preço': 8.99}]

# %% [markdown]
# ##Exercício 5: Analisando uma Lista de Tuplas
#
# - Crie uma lista de tuplas, onde cada tupla contém um par (nome, idade).
# - Encontre e imprima o nome da pessoa mais velha.
# - Encontre e imprima a idade média das pessoas.

# %%
# seu código aqui...
idade = 0
nomemaisvelho = " "

pessoas = [("Robson", 15), ("Cíntia", 29), ("Andersson", 30)]

if pessoas[0][1] > pessoas[1][1]:
    if pessoas[0][1] > pessoas[2][1]:
        nomemaisvelho = pessoas[0][0]
        idade = pessoas[0][1]
    else:
        nomemaisvelho = pessoas[2][0]
        idade = pessoas[2][1]
else:
    if pessoas[1][1] > pessoas[2][1]:
        nomemaisvelho = pessoas[1][0]
        idade = pessoas[1][1]
    else:
        nomemaisvelho = pessoas[2][0]
        idade = pessoas[2][1]


media = (pessoas[0][1] + pessoas[1][1] + pessoas[2][1])/3
print(nomemaisvelho , idade)
print(media)
# Out:
# Andersson 30
# 24.666666666666668
