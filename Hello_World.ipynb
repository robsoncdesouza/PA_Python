# %% [markdown]
# <a href="https://colab.research.google.com/github/robsoncdesouza/PA_Python/blob/main/Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Hello World

# %%
a= "hello world"

# %%
a
# Out:
# 'hello world'

# %%
print (a)
# Out:
# hello world

# %% [markdown]
# ##Área do Quadrado

# %%
# Calcular a área de um quadrado
## Entrada

## a = l.l
## l = 5
## a = l * l

l= 5
a= l * l
# Out:
# 25

# %%
print ("A área do quadrado é" , a)
# Out:
# A área do quadrado é 25
